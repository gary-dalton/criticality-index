# %% [markdown]
# # Test Runner
#
# Run the full test suite from within Jupyter.

# %%
using Test
include("test/runtests.jl");
# Out:
# ...
#   CRITICALITY INDEX — TEST SUITE
# ...
#   Working directory: /home/jovyan/work
#   Data available:    true
# ...
#
# >>> Loading Phase 0 modules...
#     ✓ All Phase 0 modules loaded
#
# >>> Running tests...
#
# Test Summary:                           | Pass  Total  Time
# Criticality Index                       | 6204   6204  4.2s
#   Phase 0: Preprocessing                | 6204   6204  4.2s
#     qog_augmented_standard              |   35     35  0.0s
#       constants defined                 |   18     18  0.0s
#       COLLISION_PRIORITY_ALPHAS         |    4      4  0.0s
#       RESCUED_ENTITY_REGIONS            |    4      4  0.0s
#       integration: load_augmented_qog   |    9      9  0.0s
#     qog_pdf_extract                     |   36     36  0.1s
#       parse_year_value                  |   21     21  0.0s
#       extract_first_paragraph           |    3      3  0.0s
#       classify_provenance               |   12     12  0.0s
# ...
